# %%
import numpy as np
import matplotlib.pyplot as plt
import glob

# %%
path = "./.."

files = glob.glob("./../*.txt")

# %%
prova = np.loadtxt(files[0])
files
# Out:
# ['./../gamma_constDI.txt',
#  './../gamma_constDLLI.txt',
#  './../gamma_constFLLI.txt',
#  './../gamma_constFI.txt',
#  './../gamma_constLDI.txt',
#  './../gamma_constLDLLI.txt']

# %%
x = []

for k in range(1,9):
    for j in range(1,10):
        
        x.append((10**k)*j)

from mpmath import *
mp.dps = 60; mp.pretty = True
+euler
# Out:
# 0.577215664901532860606512090082402431042159335939923598805767

# %%
plt.plot(x,prova,'.')
plt.title(files[0][5:-4])
plt.xlabel("Iteration", fontsize = 10)
plt.ylabel("$\gamma$")
plt.grid()
plt.axhline(+euler,color='red',lw=2, dash_joinstyle='round', alpha = 0.4)
plt.xscale('log')

# %%
prova = np.loadtxt(files[3])
plt.plot(x,prova,'.')
plt.title(files[3][5:-4])
plt.xlabel("Iteration", fontsize = 10)
plt.ylabel("$\gamma$")
plt.grid()
plt.axhline(+euler,color='red',lw=2, dash_joinstyle='round')
plt.xscale('log')

# %%
prova = np.loadtxt(files[4])
plt.plot(x,prova,'.')
plt.title(files[4][5:-4])
plt.xlabel("Iteration", fontsize = 10)
plt.ylabel("$\gamma$")
plt.grid()
plt.axhline(+euler,color='red',lw=2, dash_joinstyle='round')
plt.xscale('log')

# %%
# Out:
# ['./../gamma_constDI.txt',
#  './../gamma_constDLLI.txt',
#  './../gamma_constFLLI.txt',
#  './../gamma_constFI.txt',
#  './../gamma_constLDI.txt',
#  './../gamma_constLDLLI.txt']

# %%
x = []

N = 10;

for k in range(1,N):
    if(k==N-1):
        for j in range(1,3):
            x.append((10**k)*j)
    else:
        for i in range(1,10):
            x.append((10**k)*i)

# %%
prova = np.loadtxt(files[2])
plt.plot(x,prova,'.')
plt.title(files[2][5:-4])
plt.xlabel("Iteration", fontsize = 10)
plt.ylabel("$\gamma$")
plt.grid()
plt.axhline(+euler,color='red',lw=2, dash_joinstyle='round')
plt.xscale('log')

# %%
prova = np.loadtxt(files[1])
plt.plot(x,prova,'.')
plt.title(files[1][5:-4])
plt.xlabel("Iteration", fontsize = 10)
plt.ylabel("$\gamma$")
plt.grid()
plt.axhline(+euler,color='red',lw=2, dash_joinstyle='round')
plt.xscale('log')

# %%
prova = np.loadtxt(files[-1])
plt.plot(x,prova,'.')
plt.title(files[-1][5:-4])
plt.xlabel("Iteration", fontsize = 10)
plt.ylabel("$\gamma$")
plt.grid()
plt.axhline(+euler,color='red',lw=2, dash_joinstyle='round')
plt.xscale('log')
